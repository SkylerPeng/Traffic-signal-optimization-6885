# %%
import os
from datetime import datetime
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from cityflow_env import CityFlowEnv

# %%
# ---------------------- Basic paths and settings ----------------------

config_path = "examples/config.json"   # make sure this points to your CityFlow config
log_dir = "sb3_logs/ppo_cityflow"
os.makedirs(log_dir, exist_ok=True)

model_save_path = os.path.join(log_dir, "ppo_cityflow_model")
tensorboard_log = os.path.join(log_dir, "tb")

# number of parallel environments (start with 1 to be safe)
n_envs = 1

# %%
# ------------- Make a function that creates one CityFlow env -------------
def make_env(config_path: str, log_dir: str):
    """
    Factory function to create a single CityFlowEnv instance
    wrapped with Monitor to record episode rewards and lengths.
    """
    def _init():
        env = CityFlowEnv(config_path)
        # CSV file path
        monitor_path = os.path.join(log_dir, "monitor.csv")   
        env = Monitor(env, filename=monitor_path)
        return env
    return _init

# %%
# ---------------------- Create vectorized environment -----------------

# DummyVecEnv is used for single- or multi-env setup
env_fns = [make_env(config_path, log_dir) for _ in range(n_envs)]
vec_env = DummyVecEnv(env_fns)
# Out:
# Loading file: examples/config.json
# Successfully initialize environment: watch the crossing intersection_1_1, focus on 28

# %%
# ---------------------- Create PPO model (SB3) ------------------------

"""
MlpPolicy: a simple feed-forward neural network (MLP).
You can tune the policy_kwargs for deeper/wider networks if needed.
"""

model = PPO(
    policy="MlpPolicy",
    env=vec_env,
    learning_rate=3e-4,
    n_steps=2048,          # how many steps to collect per PPO update
    batch_size=64,
    n_epochs=10,          # mini-batch updates per PPO epoch
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    verbose=1,
    tensorboard_log=tensorboard_log,
    device="cpu",
)
# Out:
# Using cpu device

# %%
# ---------------------- Train the model -------------------------------

total_timesteps = int(5e4)

start_time = datetime.now().replace(microsecond=0)
print("===============================================================")
print("Start training at:", start_time)
print("Total timesteps:", total_timesteps)
print("Logs dir:", log_dir)
print("===============================================================")

model.learn(
    total_timesteps=total_timesteps,
    tb_log_name="PPO_CityFlow",
    progress_bar=True
)

end_time = datetime.now().replace(microsecond=0)
print("===============================================================")
print("Finished training at:", end_time)
print("Total training time:", end_time - start_time)
print("===============================================================")
# Out:
# ===============================================================
# Start training at: 2025-12-13 03:09:00
# Total timesteps: 50000
# Logs dir: sb3_logs/ppo_cityflow
# ===============================================================
# Logging to sb3_logs/ppo_cityflow/tb/PPO_CityFlow_18
# Output()
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 360       |
# |    ep_rew_mean     | -2.18e+03 |
# | time/              |           |
# |    fps             | 170       |
# |    iterations      | 1         |
# |    time_elapsed    | 12        |
# |    total_timesteps | 2048      |
# ----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | -2.08e+03   |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 2           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015702315 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | -0.00335    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.63e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0259     |
# |    value_loss           | 8.45e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | -1.98e+03   |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 3           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014157739 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.000658    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.96e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0224     |
# |    value_loss           | 7.06e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | -1.9e+03    |
# | time/                   |             |
# |    fps                  | 145         |
# |    iterations           | 4           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014480182 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.98       |
# |    explained_variance   | -0.000207   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.66e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0262     |
# |    value_loss           | 5.58e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 360       |
# |    ep_rew_mean          | -1.8e+03  |
# | time/                   |           |
# |    fps                  | 146       |
# |    iterations           | 5         |
# |    time_elapsed         | 69        |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0140293 |
# |    clip_fraction        | 0.197     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.91     |
# |    explained_variance   | -0.0013   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.12e+03  |
# |    n_updates            | 40        |
# |    policy_gradient_loss | -0.0237   |
# |    value_loss           | 4.56e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | -1.71e+03   |
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 6           |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015868608 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | -0.00254    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0211     |
# |    value_loss           | 3.06e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | -1.63e+03   |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 7           |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.014227195 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | -0.00203    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.02       |
# |    value_loss           | 2.38e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | -1.55e+03   |
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 8           |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.018218145 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | -0.00189    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 689         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.02       |
# |    value_loss           | 1.55e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | -1.47e+03   |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 9           |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010464245 |
# |    clip_fraction        | 0.0816      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | -0.00192    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 385         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 1.08e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | -1.41e+03   |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 10          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008682704 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | -0.00159    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 275         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00919    |
# |    value_loss           | 738         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | -1.35e+03   |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 11          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010261778 |
# |    clip_fraction        | 0.0755      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | -0.001      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 245         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 563         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | -1.3e+03    |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 12          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.024737962 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -0.000631   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 242         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 601         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 360        |
# |    ep_rew_mean          | -1.26e+03  |
# | time/                   |            |
# |    fps                  | 142        |
# |    iterations           | 13         |
# |    time_elapsed         | 186        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.01499453 |
# |    clip_fraction        | 0.13       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | -0.000419  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 277        |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0145    |
# |    value_loss           | 582        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | -1.24e+03   |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 14          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.013894873 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.000221   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 223         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0098     |
# |    value_loss           | 552         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 15          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.013155587 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | -0.000124   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 508         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 1.03e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | -1.2e+03    |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 16          |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.045101114 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | -0.000123   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 241         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 701         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 360          |
# |    ep_rew_mean          | -1.18e+03    |
# | time/                   |              |
# |    fps                  | 143          |
# |    iterations           | 17           |
# |    time_elapsed         | 243          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0076702917 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | -7.45e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 261          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0093      |
# |    value_loss           | 785          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 360          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 143          |
# |    iterations           | 18           |
# |    time_elapsed         | 257          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0079600215 |
# |    clip_fraction        | 0.0914       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -6.87e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 390          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00673     |
# |    value_loss           | 643          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 360          |
# |    ep_rew_mean          | -1.07e+03    |
# | time/                   |              |
# |    fps                  | 143          |
# |    iterations           | 19           |
# |    time_elapsed         | 271          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0109571945 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -6.18e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 383          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0101      |
# |    value_loss           | 654          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | -1.03e+03   |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 20          |
# |    time_elapsed         | 286         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.014937461 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -4.54e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 279         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00351    |
# |    value_loss           | 616         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | -978        |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 21          |
# |    time_elapsed         | 299         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007940753 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | -2.53e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 157         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00525    |
# |    value_loss           | 713         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | -934        |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 22          |
# |    time_elapsed         | 314         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.016307639 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -2.35e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 191         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00459    |
# |    value_loss           | 738         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 360        |
# |    ep_rew_mean          | -913       |
# | time/                   |            |
# |    fps                  | 143        |
# |    iterations           | 23         |
# |    time_elapsed         | 327        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.07664779 |
# |    clip_fraction        | 0.187      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | -1.91e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 333        |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00907   |
# |    value_loss           | 720        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | -888        |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 24          |
# |    time_elapsed         | 343         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007105056 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -9.54e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 280         |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00152    |
# |    value_loss           | 757         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 360        |
# |    ep_rew_mean          | -872       |
# | time/                   |            |
# |    fps                  | 143        |
# |    iterations           | 25         |
# |    time_elapsed         | 357        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.02507034 |
# |    clip_fraction        | 0.145      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.766     |
# |    explained_variance   | -9.18e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 791        |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0111    |
# |    value_loss           | 752        |
# ----------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ===============================================================
# Finished training at: 2025-12-13 03:14:58
# Total training time: 0:05:58
# ===============================================================

# %%
# ---------------------- Save trained model ----------------------------

model.save(model_save_path)
print(f"Model saved to: {model_save_path}")
# Out:
# Model saved to: sb3_logs/ppo_cityflow/ppo_cityflow_model

# %%
# ---------------------- Simple evaluation ------------------

# you can reload the model and run a few episodes for evaluation

eval_episodes = 5
env = CityFlowEnv(config_path)   # a fresh instance for evaluation (no Monitor)

for ep in range(eval_episodes):
    # gymnasium-compatible reset: (obs, info)
    reset_out = env.reset()
    if isinstance(reset_out, tuple):
        state, info = reset_out
    else:
        state = reset_out

    done = False
    ep_reward = 0.0
    step_count = 0
    
    while not done:
        # SB3 model expects a batch of observations
        action, _ = model.predict(state, deterministic=True)

        step_out = env.step(action)

        # support both gymnasium (obs, reward, terminated, truncated, info)
        # and gym (obs, reward, done, info)
        if len(step_out) == 5:
            next_state, reward, terminated, truncated, info = step_out
            done = terminated or truncated
        else:
            next_state, reward, done, info = step_out

        ep_reward += reward
        step_count += 1
        state = next_state

    print(f"[Eval] Episode {ep+1}: reward={ep_reward}, steps={step_count}")

env.close()
vec_env.close()
# Out:
# Loading file: examples/config.json
# Successfully initialize environment: watch the crossing intersection_1_1, focus on 28
# [Eval] Episode 1: reward=-661.7000000000055, steps=360
# [Eval] Episode 2: reward=-667.4000000000055, steps=360
# [Eval] Episode 3: reward=-664.5000000000055, steps=360
# [Eval] Episode 4: reward=-661.9000000000054, steps=360
# [Eval] Episode 5: reward=-664.4000000000055, steps=360

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Path to the Monitor CSV file
monitor_path = os.path.join(log_dir, "monitor.csv")

# Skip the first row because it contains comments
df = pd.read_csv(monitor_path, skiprows=1)

# Episode rewards
rewards = df["r"].to_numpy()

# Moving average window
window = 20
moving_avg = pd.Series(rewards).rolling(window).mean()

# Plot rewards
plt.figure(figsize=(10, 4))
plt.plot(rewards, label="Episode Reward", alpha=0.6)
plt.plot(moving_avg, label=f"Moving Average ({window})", linewidth=2)
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.title("Training Rewards")
plt.legend()
plt.grid(True)
plt.show()

# %%
import os
import glob
import matplotlib.pyplot as plt
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator

# Find TensorBoard event files
event_files = glob.glob(
    os.path.join(tensorboard_log, "**", "events.out.tfevents.*"),
    recursive=True
)

assert len(event_files) > 0, "No TensorBoard event files found."

# Use the latest event file
event_file = sorted(event_files, key=os.path.getmtime)[-1]
print("Using event file:", event_file)

# Load TensorBoard events
ea = EventAccumulator(event_file)
ea.Reload()

# Print available scalar tags
print("Available scalar tags:")
print(ea.Tags()["scalars"])

# Keep only meaningful PPO losses
loss_tags = [
    "train/loss",
    "train/value_loss",
]

# Keep only existing tags (safe for different SB3 versions)
loss_tags = [tag for tag in loss_tags if tag in ea.Tags()["scalars"]]
assert len(loss_tags) > 0, "No loss-related tags found."

# Plot
plt.figure(figsize=(10, 4))
for tag in loss_tags:
    events = ea.Scalars(tag)
    steps = [e.step for e in events]
    values = [e.value for e in events]
    plt.plot(steps, values, label=tag)

plt.xlabel("Timesteps")
plt.ylabel("Loss Value")
plt.title("Training Loss Curves (PPO)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Using event file: sb3_logs/ppo_cityflow/tb/PPO_CityFlow_18/events.out.tfevents.1765613340.localhost.17943.0
# Available scalar tags:
# ['rollout/ep_len_mean', 'rollout/ep_rew_mean', 'time/fps', 'train/approx_kl', 'train/clip_fraction', 'train/clip_range', 'train/entropy_loss', 'train/explained_variance', 'train/learning_rate', 'train/loss', 'train/policy_gradient_loss', 'train/value_loss']
